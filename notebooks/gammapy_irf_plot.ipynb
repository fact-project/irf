# %%
from gammapy.irf import EffectiveAreaTable2D
from gammapy.irf import EnergyDispersion2D
from gammapy.irf import PSF3D
import astropy.units as u
# %matplotlib inline

# %%
path = './../cta_irf.fits'
aeff = EffectiveAreaTable2D.read(path, hdu='EFFECTIVE AREA')
aeff.peek()

# %%
edisp = EnergyDispersion2D.read(path, hdu='ENERGY DISPERSION')
edisp.peek()

# %%
psf = PSF3D.read(path,  hdu='POINT SPREAD FUNCTION')
psf.peek()
print(psf.info())
# Out:
# /usr/local/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py:175: RuntimeWarning: invalid value encountered in greater
#   if not all(diff(x) > 0.0):
# /Users/mackaiver/Development/gammapy/gammapy/irf/psf_3d.py:370: RuntimeWarning: All-NaN slice encountered
#   kwargs.setdefault('vmin', np.nanmin(containment.value))
# /Users/mackaiver/Development/gammapy/gammapy/irf/psf_3d.py:371: RuntimeWarning: All-NaN slice encountered
#   kwargs.setdefault('vmax', np.nanmax(containment.value))
# /usr/local/lib/python3.6/site-packages/numpy/core/_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# /usr/local/lib/python3.6/site-packages/numpy/core/_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# Summary PSF3D info
# ---------------------
# energy_lo      : size =    25, min =  0.010 TeV, max = 69.183 TeV
# ...

# %%
k = psf.to_table_psf(energy=1*u.TeV)
# Out:
# /usr/local/lib/python3.6/site-packages/scipy/interpolate/fitpack2.py:175: RuntimeWarning: invalid value encountered in greater
#   if not all(diff(x) > 0.0):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-85a684dc3a43> in <module>()
# ----> 1 k = psf.to_table_psf(energy=1*u.TeV)
#
# ~/Development/gammapy/gammapy/irf/psf_3d.py in to_table_psf(self, energy, theta, interp_kwargs, **kwargs)
#     261         psf_value = self.evaluate(energy, theta, interp_kwargs=interp_kwargs).squeeze()
#     262         rad = self._rad_center()
# --> 263         table_psf = TablePSF(rad, psf_value, **kwargs)
#     264
#     265         return table_psf
#
# ~/Development/gammapy/gammapy/irf/psf_table.py in __init__(self, rad, dp_domega, spline_kwargs)
#      73         self._spline_kwargs = spline_kwargs
#      74
# ---> 75         self._compute_splines(spline_kwargs)
# ...

# %%
print(k.info())
# Out:
# offset         : size =    30, min =  0.333, max = 19.667
# integral = 11.449704556420642
# containment radius 1.1433141764014574 deg for 50%
# containment radius 1.2534226180958388 deg for 68%
# containment radius 1.3268282458920932 deg for 80%
# containment radius 1.4185852806374113 deg for 95%

# %%
e = psf.to_energy_dependent_table_psf()

# %%
print(e)
